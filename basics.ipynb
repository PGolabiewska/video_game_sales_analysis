# %%
import numpy as np
import pandas as pd
import matplotlib as plt
pd.set_option("display.width", 1000)

df = pd.read_csv("data\\games_data.csv")
print(df.head())
# Out:
#                                              img                        title console    genre       publisher       developer  critic_score  total_sales  na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32      6.37      0.99       9.85         3.12   2013-09-17         NaN
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39      6.06      0.60       9.71         3.02   2014-11-18  2018-01-03
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15      8.41      0.47       5.49         1.78   2002-10-28         NaN
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V    X360   Action  Rockstar Games  Rockstar North           NaN        15.86      9.06      0.06       5.33         1.42   2013-09-17         NaN
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3     PS4  Shooter      Activision        Treyarch           8.1        15.09      6.18      0.41       6.05         2.44   2015-11-06  2018-01-14

# %%
a = df.loc[df["console"] == "PC", ["title", "console", "genre", "publisher", "total_sales"]]
a = a.sort_values("total_sales", ascending=False)
print(a.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 3
#       1 # a = df[df["console"] == "PC"][['title', 'console', 'genre', 'publisher']]
#       2 a = df.loc[df["console"] == "PC", ['title', 'console', 'genre', 'publisher']]
# ----> 3 a = a.sort_values("total_sales", ascending=False)
#       4 print(a.head(10))
#
# File e:\Projects\video_game_sales_analysis\venv\Lib\site-packages\pandas\core\frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# File e:\Projects\video_game_sales_analysis\venv\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'total_sales'
