# %%
import numpy as np
import pandas as pd
import matplotlib as plt
pd.set_option("display.width", 1000)

df = pd.read_csv("data\\games_data.csv")
print(df.head())
# Out:
#                                              img                        title console    genre       publisher       developer  critic_score  total_sales  na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32      6.37      0.99       9.85         3.12   2013-09-17         NaN
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39      6.06      0.60       9.71         3.02   2014-11-18  2018-01-03
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15      8.41      0.47       5.49         1.78   2002-10-28         NaN
# ...

# %%
a = df.loc[df["console"] == "PC", ["title", "console", "genre", "publisher", "total_sales"]]
a = a.sort_values("total_sales", ascending=False).reset_index(drop=True)
a.index = range(1, len(a) + 1)

print(a.head(10))
# Out:
#                            title console         genre           publisher  total_sales
# 34                    The Sims 3      PC    Simulation     Electronic Arts         7.96
# 79    Microsoft Flight Simulator      PC    Simulation           Microsoft         5.12
# 144                   The Sims 4      PC    Simulation     Electronic Arts         4.10
# 154  The Elder Scrolls V: Skyrim      PC  Role-Playing  Bethesda Softworks         3.99
# 166          The Sims: Unleashed      PC    Simulation     Electronic Arts         3.76
# 181                      Doom II      PC       Shooter      GT Interactive         3.61
# 253           The Sims: Vacation      PC    Simulation     Electronic Arts         3.07
# 262        The Sims: Livin Large      PC          Misc     Electronic Arts         2.99
# 304                Battlefield 3      PC       Shooter     Electronic Arts         2.76
# 388               Theme Hospital      PC      Strategy     Electronic Arts         2.40
